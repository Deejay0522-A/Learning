# %% [markdown]
# # FastHTML Documentation
# ###### By: Denise Lopez | Started: 7/2/2026
#
# #### Important Starting Functions

# %%
from fasthtml.common import * # imports all common fasthtml functions
from starlette.background import BackgroundTask # imports backend handling within the python file

# %% [markdown]
# There are also many ways to incorporate the HTML, such as:
# - app = FastHTML() | This allows for specified route definitions, such as "@app.{get | update | post | remove}"
# - app, rt = fast_app() | Allows for shortened route names and allows methods, such as "@rt('/', methods=['post'])"

# %%
# Make sure you use the imports first. Use serve() after

app = FastHTML()

@app.get('/')
def Home():
    return P("Hello World!")

serve() # Used when setting up server
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
